# %%
from get_sentiment import get_sentiment
import pandas as pd

# %%
text = ['Unemployment is rising at high speed', 'The economy is slowing down and unemployment is booming']
include = ['unemployment', 'economy']

get_sentiment(text = text, include = include)
# Out:
#    Doc_id                                               Text  \
# 0       0             [Unemployment is rising at high speed]
# 1       1  [The economy is slowing down and unemployment ...
# 2       1  [The economy is slowing down and unemployment ...
#
#                               SpannedText  \
# 0  [Unemployment is rising at high speed]
# 1                    [economy is slowing]
# 2               [unemployment is booming]
#
#                                                Chunk  Sentiment      Tense  \
# 0  ---unemployment---+++___rise [VERB, VBG (0.55)...   -0.89875  [present]
# 1            ---economy---+++slow [VERB, VBG (-0.3)]   -0.30000  [present]
# 2        ---unemployment---+++boom [VERB, VBG (0.8)]   -0.80000  [present]
#
#           Include
# 0  [unemployment]
# 1       [economy]
# 2  [unemployment]

# %%
df = pd.read_pickle(r'top_n_words_tfidf.pkl')
display(df)
# Out:
#      article                  file_path  \
# 0    4509509  data/earning_call/4509509
# 1    4508877  data/earning_call/4508877
# 2    4509199  data/earning_call/4509199
# 3    4509360  data/earning_call/4509360
# 4    4509536  data/earning_call/4509536
# ..       ...                        ...
# 778  4508661  data/earning_call/4508661
# 779  4508659  data/earning_call/4508659
# 780  4508833  data/earning_call/4508833
# 781  4509740  data/earning_call/4509740
# 782  4509324  data/earning_call/4509324
#
#                                            top_n_words
# 0    [3pl, peloton, savings, stabler, hardware, app...
# 1    [oneweb, caleb, backhaul, anders, bharti, 3gpp...
# 2    [patients, oxybates, avadel, francois, sodium,...
# 3    [brooks, clinicians, daniels, notes, klee, all...
# 4    [merchants, cupito, zayas, siegler, 842, medli...
# ..                                                 ...
# 778  [silber, rosenbaum, shlomo, students, enrollme...
# 779  [patients, cells, gil, morphological, futility...
# 780  [malaysia, telephonics, bucknall, crawford, to...
# 781  [fibroids, gnrh, uneek, endometriosis, women, ...
# 782  [aco, garipalli, ca, dce, derrick, pcps, nuema...
#
# [783 rows x 3 columns]

# %%
with open(df.file_path[0]) as file:
    earning_call = file.read()
    include = df.top_n_words
    result = get_sentiment(text = earning_call, include = include)
    display(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 with open(df.file_path[0]) as file:
#       2     earning_call = file.read()
#       3     include = df.top_n_words
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/earning_call/4509509'

# %%
with open("data/earning_call/4508397","r") as file:
    earning_call = file.read()
    #tmp = earning_call.replace("\n", ".").split(".")
    #earning_call = []
    #to_remove = ['', ' ']
    #for word in tmp:
    #    if word not in to_remove:
    #        earning_call.append(word)
    #print(earning_call)
    include = ['quarter', "business"]
    result = get_sentiment(text = [earning_call], include= include)
    display(result)
