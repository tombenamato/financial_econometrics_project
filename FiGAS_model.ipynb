# %%
from get_sentiment import get_sentiment

# %%
text = ['Unemployment is rising at high speed', 'The economy is slowing down and unemployment is booming']
include = ['unemployment', 'economy']

get_sentiment(text = text, include = include)
# Out:
#    Doc_id                                               Text  \
# 0       0             [Unemployment is rising at high speed]
# 1       1  [The economy is slowing down and unemployment ...
# 2       1  [The economy is slowing down and unemployment ...
#
#                               SpannedText  \
# 0  [Unemployment is rising at high speed]
# 1                    [economy is slowing]
# 2               [unemployment is booming]
#
#                                                Chunk  Sentiment      Tense  \
# 0  ---unemployment---+++___rise [VERB, VBG (0.55)...   -0.89875  [present]
# 1            ---economy---+++slow [VERB, VBG (-0.3)]   -0.30000  [present]
# 2        ---unemployment---+++boom [VERB, VBG (0.8)]   -0.80000  [present]
#
#           Include
# 0  [unemployment]
# 1       [economy]
# 2  [unemployment]

# %%
with open("data/earning_call/4508397","r") as file:
    earning_call = file.read()
    #tmp = earning_call.replace("\n", ".").split(".")
    #earning_call = []
    #to_remove = ['', ' ']
    #for word in tmp:
    #    if word not in to_remove:
    #        earning_call.append(word)
    #print(earning_call)
    include = ['quarter', "business"]
    result = get_sentiment(text = [earning_call], include= include)
    display(result)
# Out:
#     Doc_id                                               Text  \
# 0        0  [James Kisner Thank you, and good afternoon, a...
# 1        0  [Statements on this call include forward-looki...
# 2        0  [Our B2 Cloud Storage business grew at strong ...
# 3        0  [Our B2 Cloud Storage business grew at strong ...
# 4        0  [While the Computer Backup business remains th...
# 5        0  [SoDA specializes in helping businesses move t...
# 6        0  [Working down the P&L, adjusted gross margin, ...
# 7        0  [For the second quarter, we expect revenue to ...
# 8        0  [As such, we think for modeling purposes that ...
# 9        0  [What we've seen is something that happened in...
# 10       0  [It's actually up a little bit from the prior ...
# 11       0  [Last quarter, you noted that you were going t...
# 12       0  [We've had to take several quarters to see the...
# 13       0  [We hired up our sales team in the first quart...
# 14       0  [And then the other item that we highlighted l...
# 15       0  [But I wouldn't say the competitive landscape ...
# 16       0  [So, I think what Eric was asking was, there w...
# 17       0  [You're asking how did we accelerate growth up...
# 18       0  [Yes, the Computer Backup side, we continue to...
# 19       0  [The fundamentals we continue to hear from cus...
# 20       0  [The fundamentals we continue to hear from cus...
# 21       0  [So, they continue to want to run their busine...
# 22       0  [But in the face of all that, they're trying t...
# 23       0  [And so to the extent that they're continuing ...
# 24       0  [But they're also trying to continue to run th...
# 25       0  [Our B2 Cloud Storage offering already support...
# 26       0  [B2 Cloud Storage actually came about in part ...
# 27       0  [So given that B2 has a very high revenue per ...
# 28       0  [Our Computer Backup services serves both busi...
# 29       0  [B2 Cloud Storage is primarily focused on supp...
# 30       0  [And so as much as we continue to make it easy...
# 31       0  [Is Backblaze planning any major acquisitions ...
#
#                                           SpannedText  \
# 0   [first quarter of fiscal year 2022 earnings call]
# 1       [expand our business with existing customers]
# 2                                  [business grew at]
# 3                                     [business grew]
# 4   [business remains the larger of our two cloud ...
# 5   [businesses move their data from on-premise to...
# 6                                      [last quarter]
# 7                                    [second quarter]
# 8                                [last four quarters]
# 9                                     [first quarter]
# 10                                    [prior quarter]
# 11                          [Last quarter, you noted]
# 12  [take several quarters to see the results of t...
# 13                                 [first quarter of]
# 14                         [highlighted last quarter]
# 15                                     [last quarter]
# 16                     [further quarters of the year]
# 17                                    [prior quarter]
# 18  [grow that business through acquiring more cus...
# 19                             [run their businesses]
# 20                     [running their businesses for]
# 21                             [run their businesses]
# 22                             [run their businesses]
# 23                             [run their businesses]
# 24                                 [run the business]
# 25                [supports businesses for the users]
# 26                [many businesses came to us saying]
# 27                               [larger business in]
# 28                           [serves both businesses]
# 29                            [supporting businesses]
# 30  [showed this quarter with the announcement tod...
# 31                                     [next quarter]
#
#                                                 Chunk  Sentiment      Tense  \
# 0   ---quarter---+++first [ADJ, JJ (0.0)]+++___cal...    0.00000      [NaN]
# 1   ---business---+++___expand [VERB, VB (0.35)]__...    0.43125  [present]
# 2             ---business---+++grow [VERB, VBD (0.6)]    0.60000     [past]
# 3             ---business---+++grow [VERB, VBD (0.6)]    0.60000     [past]
# 4   ---business---+++___remain [VERB, VBZ (0.0)]__...    0.00000  [present]
# 5   ---business---+++___ensure [VERB, VBG (0.2)]__...    0.26000  [present]
# 6                ---quarter---+++last [ADJ, JJ (0.0)]    0.00000      [NaN]
# 7              ---quarter---+++second [ADJ, JJ (0.0)]    0.00000      [NaN]
# 8                ---quarter---+++last [ADJ, JJ (0.0)]    0.00000      [NaN]
# 9               ---quarter---+++first [ADJ, JJ (0.0)]    0.00000      [NaN]
# 10              ---quarter---+++prior [ADJ, JJ (0.0)]    0.00000      [NaN]
# 11  ---quarter---+++last [ADJ, JJ (0.0)]+++note [V...    0.00000     [past]
# 12  ---quarter---+++several [ADJ, JJ (0.0)]+++___s...   -0.25000      [NaN]
# 13              ---quarter---+++first [ADJ, JJ (0.0)]    0.00000      [NaN]
# 14  ---quarter---+++last [ADJ, JJ (0.0)]+++highlig...    0.35000     [past]
# 15               ---quarter---+++last [ADJ, JJ (0.0)]    0.00000      [NaN]
# 16  ---quarter---+++further [ADJ, JJ (-0.125)]+++_...   -0.12500      [NaN]
# 17              ---quarter---+++prior [ADJ, JJ (0.0)]    0.00000      [NaN]
# 18  ---business---+++___grow [VERB, VB (0.6)]_____...    0.86000  [present]
# 19              ---business---+++run [VERB, VB (0.0)]    0.00000      [NaN]
# 20             ---business---+++run [VERB, VBG (0.0)]    0.00000  [present]
# 21              ---business---+++run [VERB, VB (0.0)]    0.00000      [NaN]
# 22              ---business---+++run [VERB, VB (0.0)]    0.00000      [NaN]
# 23              ---business---+++run [VERB, VB (0.0)]    0.00000      [NaN]
# 24              ---business---+++run [VERB, VB (0.0)]    0.00000      [NaN]
# 25  ---business---+++___support [VERB, VBZ (0.55)]...    0.55000  [present]
# 26  ---business---+++many [ADJ, JJ (0.0)]+++say [V...    0.00000     [past]
# 27            ---business---+++large [ADJ, JJR (0.6)]    0.60000      [NaN]
# 28           ---business---+++serve [VERB, VBZ (0.0)]    0.00000  [present]
# 29        ---business---+++support [VERB, VBG (0.55)]    0.55000  [present]
# 30  ---quarter---+++___serve [VERB, VB (0.0)]_____...    0.00000     [past]
# 31               ---quarter---+++next [ADJ, JJ (0.0)]    0.00000      [NaN]
#
#        Include
# 0    [quarter]
# 1   [business]
# 2   [business]
# 3   [business]
# 4   [business]
# 5   [business]
# 6    [quarter]
# 7    [quarter]
# 8    [quarter]
# 9    [quarter]
# 10   [quarter]
# 11   [quarter]
# 12   [quarter]
# 13   [quarter]
# 14   [quarter]
# 15   [quarter]
# 16   [quarter]
# 17   [quarter]
# 18  [business]
# 19  [business]
# 20  [business]
# 21  [business]
# 22  [business]
# 23  [business]
# 24  [business]
# 25  [business]
# 26  [business]
# 27  [business]
# 28  [business]
# 29  [business]
# 30   [quarter]
# 31   [quarter]
